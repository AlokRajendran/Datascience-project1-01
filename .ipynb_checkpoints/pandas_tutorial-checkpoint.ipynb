# %% [markdown]
# # Pandas

# %% [markdown]
# Is powerful python data analysis toolkit for reading,filtering,manipulating,visualizing and exporting data

# %% [markdown]
# Reading different varities of data. eg:csv,json etc

# %% [markdown]
# Functions for filtering,selecting and  manipulating data

# %% [markdown]
# Plotting data for visualization and exploration purpose

# %%
#Reading different files
#csv files-read_csv
#ms excel-read_excel

# %%
#importing pandas library
import pandas as pd

# %%
#reading the csv file
df=pd.read_csv("salaries.csv")

# %%
df.head()
# Out:
#   company                  job     degree  salary_more_then_100k
# 0  google      sales executive  bachelors                      0
# 1  google      sales executive    masters                      0
# 2  google     business manager  bachelors                      1
# 3  google     business manager    masters                      1
# 4  google  computer programmer  bachelors                      0

# %%
#reading excel file
#df1=pd.read_excel("data.xlsx")

# %% [markdown]
# # Dataframe

# %% [markdown]
# Similar to excel workbook tabular datasheet

# %%
#DataFrame.shape()
#DataFrame.columns()

# %%
#seeing the dimension of the df dataframe

# %%
df.shape
# Out:
# (16, 4)

# %%
#op 3 rows

# %%
df.head(3)
# Out:
#   company               job     degree  salary_more_then_100k
# 0  google   sales executive  bachelors                      0
# 1  google   sales executive    masters                      0
# 2  google  business manager  bachelors                      1

# %%
#last 5 rows

# %%
df.tail(5)
# Out:
#      company                  job     degree  salary_more_then_100k
# 11  facebook      sales executive    masters                      1
# 12  facebook     business manager  bachelors                      1
# 13  facebook     business manager    masters                      1
# 14  facebook  computer programmer  bachelors                      1
# 15  facebook  computer programmer    masters                      1

# %%
#seeing the names of columns in dataframe

# %%
df.columns
# Out:
# Index(['company', 'job', 'degree', 'salary_more_then_100k'], dtype='object')

# %%
#selecting a single column

# %%
df["job"]
# Out:
# 0         sales executive
# 1         sales executive
# 2        business manager
# 3        business manager
# 4     computer programmer
# 5     computer programmer
# 6         sales executive
# 7     computer programmer
# 8        business manager
# 9        business manager
# 10        sales executive
# 11        sales executive
# 12       business manager
# 13       business manager
# 14    computer programmer
# 15    computer programmer
# Name: job, dtype: object

# %%
#selecting multiple column using names

# %%
df[["company","job","degree"]]
# Out:
#        company                  job     degree
# 0       google      sales executive  bachelors
# 1       google      sales executive    masters
# 2       google     business manager  bachelors
# 3       google     business manager    masters
# 4       google  computer programmer  bachelors
# 5       google  computer programmer    masters
# 6   abc pharma      sales executive    masters
# 7   abc pharma  computer programmer  bachelors
# 8   abc pharma     business manager  bachelors
# 9   abc pharma     business manager    masters
# 10    facebook      sales executive  bachelors
# 11    facebook      sales executive    masters
# 12    facebook     business manager  bachelors
# 13    facebook     business manager    masters
# 14    facebook  computer programmer  bachelors
# 15    facebook  computer programmer    masters

# %%
#selecting rows by their position

# %%
df.iloc[:5]
# Out:
#   company                  job     degree  salary_more_then_100k
# 0  google      sales executive  bachelors                      0
# 1  google      sales executive    masters                      0
# 2  google     business manager  bachelors                      1
# 3  google     business manager    masters                      1
# 4  google  computer programmer  bachelors                      0

# %%
#selecting columns by their position

# %%
df.iloc[:,:2]
# Out:
#        company                  job
# 0       google      sales executive
# 1       google      sales executive
# 2       google     business manager
# 3       google     business manager
# 4       google  computer programmer
# 5       google  computer programmer
# 6   abc pharma      sales executive
# 7   abc pharma  computer programmer
# 8   abc pharma     business manager
# 9   abc pharma     business manager
# 10    facebook      sales executive
# 11    facebook      sales executive
# 12    facebook     business manager
# 13    facebook     business manager
# 14    facebook  computer programmer
# 15    facebook  computer programmer

# %%
df[df["salary_more_then_100k"]==1]
# Out:
#        company                  job     degree  salary_more_then_100k
# 2       google     business manager  bachelors                      1
# 3       google     business manager    masters                      1
# 5       google  computer programmer    masters                      1
# 9   abc pharma     business manager    masters                      1
# 10    facebook      sales executive  bachelors                      1
# 11    facebook      sales executive    masters                      1
# 12    facebook     business manager  bachelors                      1
# 13    facebook     business manager    masters                      1
# 14    facebook  computer programmer  bachelors                      1
# 15    facebook  computer programmer    masters                      1

# %%
#excercise

# %%
import pandas as pd

# %%
df1=pd.read_csv("index.csv")

# %%
df1.head()
# Out:
#    A  B  C   D  E  F      G      H       I    J  K  L
# 0  C  A  8   0  S  0   COIL  0.700   610.0    0  0  3
# 1  C  R  0   0  S  0   COIL  3.200   610.0    0  0  3
# 2  C  R  0   0  S  0  SHEET  0.700  1300.0  762  0  3
# 3  C  A  0  60  ?  0   COIL  2.801   385.1    0  0  3
# 4  C  A  0  60  ?  0  SHEET  0.801   255.0  269  0  3

# %%
#access the third column of  the index dataframe

# %%
df1["C"]
# Out:
# 0       8
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 252     0
# 253     6
# 254     0
# 255    45
# 256     6
# Name: C, Length: 257, dtype: int64

# %%
#Access the last two columns of the index dataframe using iloc fn

# %%
n=2
df1.iloc[:,-2:]
# Out:
#      K  L
# 0    0  3
# 1    0  3
# 2    0  3
# 3    0  3
# 4    0  3
# ..  .. ..
# 252  0  3
# 253  0  3
# 254  0  3
# 255  0  3
# 256  0  3
#
# [257 rows x 2 columns]

# %%
#Access the last ten rows and the first two columns of the index dataframe

# %%
df1.iloc[-10:,0:2]
# Out:
#      A  B
# 247  C  R
# 248  C  A
# 249  C  A
# 250  C  R
# 251  C  A
# 252  C  A
# 253  C  R
# 254  C  A
# 255  C  K
# 256  C  R

# %% [markdown]
# # Data Manipulation and visualization

# %% [markdown]
# Pandas is the most widely used library of python for data science. It is incredibly helpful for manipulating data so that you can derive better insights and build great machine learning algorithms.

# %%
import numpy as np
import pandas as pd

# %%
#read the dataset
df=pd.read_csv("bigmart_data.csv")
df
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
#drop the null values

# %%
df=df.dropna(how="any")

# %%
#view the top resuls

# %%
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15        9.300          Low Fat         0.016047
# 1           DRC01        5.920          Regular         0.019278
# 2           FDN15       17.500          Low Fat         0.016760
# 4           NCD19        8.930          Low Fat         0.000000
# 5           FDP36       10.395          Regular         0.000000
#
#       Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 0         Dairy  249.8092            OUT049                       1999
# 1   Soft Drinks   48.2692            OUT018                       2009
# 2          Meat  141.6180            OUT049                       1999
# 4     Household   53.8614            OUT013                       1987
# 5  Baking Goods   51.4008            OUT018                       2009
#
#   Outlet_Size Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# 0      Medium               Tier 1  Supermarket Type1          3735.1380
# ...

# %% [markdown]
# #sorting dataframes

# %%
#Two useful functions
#sort_values():sort dataframe by one or more coulmns
#sort_index(): sort dataframe by  raw index

# %%
#sort by year
sorted_data=df.sort_values(by="Outlet_Establishment_Year")
#print sorted data
sorted_data[:5]
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 2812           FDR60        14.30          Low Fat         0.130307
# 5938           NCJ06        20.10          Low Fat         0.034624
# 3867           FDY38        13.60          Regular         0.119077
# 1307           FDB37        20.25          Regular         0.022922
# 5930           NCA18        10.10          Low Fat         0.056031
#
#          Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 2812  Baking Goods   75.7328            OUT013                       1987
# 5938     Household  118.9782            OUT013                       1987
# 3867         Dairy  231.2300            OUT013                       1987
# 1307  Baking Goods  240.7538            OUT013                       1987
# 5930     Household  115.1492            OUT013                       1987
#
#      Outlet_Size Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# ...

# %% [markdown]
# sort values takesplace multiple options
# ascending:The default sorting order is ascending,when you pass false here
# inplace:whether to do inplace sorting or not

# %%
#sort in place and descending order

# %%
df.sort_values(by="Outlet_Establishment_Year",ascending=False,inplace=True)
df[:5]
# Out:
# <ipython-input-43-297af655886c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.sort_values(by="Outlet_Establishment_Year",ascending=False,inplace=True)
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 2825           FDL16        12.85          Low Fat         0.169139
# 7389           NCD42        16.50          Low Fat         0.012689
# 2165           DRJ39        20.25          Low Fat         0.036474
# 2162           FDR60        14.30          Low Fat         0.130946
# 2158           FDM58        16.85          Regular         0.080015
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 2825        Frozen Foods   46.4060            OUT018
# 7389  Health and Hygiene   39.7506            OUT018
# 2165               Dairy  218.3482            OUT018
# ...

# %% [markdown]
# sort a dataframe,baesd on the values of multiple columns.wwe can specify the columns we want to sort by a list in the argument for sort_values()

# %%
#read the dataset

# %%
df1=pd.read_csv("bigmart_data.csv")
#drop the null values
df1=df1.dropna(how="any")
#sort by multiple column
df1.sort_values(by=["Outlet_Establishment_Year","Item_Outlet_Sales"],ascending="false")[:5]
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 2370           NCA06       20.500          Low Fat         0.143164
# 4174           FDI60        7.220          Regular         0.038289
# 2244           FDZ27        7.935               LF         0.017142
# 3684           FDV38       19.250          Low Fat         0.101689
# 1209           FDU21       11.800              reg         0.076657
#
#          Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 2370     Household   34.9190            OUT013                       1987
# 4174  Baking Goods   64.7510            OUT013                       1987
# 2244         Dairy   50.0350            OUT013                       1987
# 3684         Dairy   54.6956            OUT013                       1987
# 1209   Snack Foods   32.3558            OUT013                       1987
#
#      Outlet_Size Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# ...

# %% [markdown]
# # Merging Dataframes

# %% [markdown]
# 1.merge()
# 2.concat()

# %%
df1=pd.DataFrame({"A":["AB","BC","CB"],"B":["CS","VM","AM"],"C":["DN","AS","VC"]})
df2=pd.DataFrame({"D":["CS","BN","HN"],"V":["HG","N","DF"],"F":["WE","RT","TY"]})

# %%
result=pd.concat([df1,df2])
result
# Out:
#      A    B    C    D    V    F
# 0   AB   CS   DN  NaN  NaN  NaN
# 1   BC   VM   AS  NaN  NaN  NaN
# 2   CB   AM   VC  NaN  NaN  NaN
# 0  NaN  NaN  NaN   CS   HG   WE
# 1  NaN  NaN  NaN   BN    N   RT
# 2  NaN  NaN  NaN   HN   DF   TY

# %%
result=pd.merge(df1,df2,how="right")
result
# Out:
# ---------------------------------------------------------------------------
# MergeError                                Traceback (most recent call last)
# <ipython-input-60-0e4251604ff2> in <module>
# ----> 1 result=pd.merge(df1,df2,how="right")
#       2 result
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      72     validate=None,
#      73 ) -> "DataFrame":
# ---> 74     op = _MergeOperation(
#      75         left,
#      76         right,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     643             warnings.warn(msg, UserWarning)
#     644
# --> 645         self._validate_specification()
#     646
#     647         # note this function has side effects
#
# ...
