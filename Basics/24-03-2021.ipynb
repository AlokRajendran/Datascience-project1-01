# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv("homeprices (2).csv")
data
# Out:
#                town  area   price
# 0   monroe township  2600  550000
# 1   monroe township  3000  565000
# 2   monroe township  3200  610000
# 3   monroe township  3600  680000
# 4   monroe township  4000  725000
# 5      west windsor  2600  585000
# 6      west windsor  2800  615000
# 7      west windsor  3300  650000
# 8      west windsor  3600  710000
# 9       robinsville  2600  575000
# 10      robinsville  2900  600000
# 11      robinsville  3100  620000
# 12      robinsville  3600  695000

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
le.fit_transform(data.town)
# Out:
# array([0, 0, 0, 0, 0, 2, 2, 2, 2, 1, 1, 1, 1])

# %%
dd=data

# %%
dd.town=le.fit_transform(dd.town)

# %%
dd
# Out:
#     town  area   price
# 0      0  2600  550000
# 1      0  3000  565000
# 2      0  3200  610000
# 3      0  3600  680000
# 4      0  4000  725000
# 5      2  2600  585000
# 6      2  2800  615000
# 7      2  3300  650000
# 8      2  3600  710000
# 9      1  2600  575000
# 10     1  2900  600000
# 11     1  3100  620000
# 12     1  3600  695000

# %% [markdown]
# ### Linear regression
# Linear regression is a linear model, e.g. a model that assumes a linear relationship between the input variables (x) and the single output variable (y). ... Different techniques can be used to prepare or train the linear regression equation from data, the most common of which is called Ordinary Least Squares.

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()

# %%
model.fit(data[['town','area']],data.price)
# Out:
# LinearRegression()

# %%
model.score(data[['town','area']],data.price)
# Out:
# 0.9552018104317441

# %%
data
# Out:
#     town  area   price
# 0      0  2600  550000
# 1      0  3000  565000
# 2      0  3200  610000
# 3      0  3600  680000
# 4      0  4000  725000
# 5      2  2600  585000
# 6      2  2800  615000
# 7      2  3300  650000
# 8      2  3600  710000
# 9      1  2600  575000
# 10     1  2900  600000
# 11     1  3100  620000
# 12     1  3600  695000

# %%
dummy=pd.get_dummies(data.town)
dummy
# Out:
#     0  1  2
# 0   1  0  0
# 1   1  0  0
# 2   1  0  0
# 3   1  0  0
# 4   1  0  0
# 5   0  0  1
# 6   0  0  1
# 7   0  0  1
# 8   0  0  1
# 9   0  1  0
# 10  0  1  0
# 11  0  1  0
# 12  0  1  0

# %%
df=pd.concat((data.drop("town",axis=1),dummy),axis=1)

# %%
df.head()
# Out:
#    area   price  0  1  2
# 0  2600  550000  1  0  0
# 1  3000  565000  1  0  0
# 2  3200  610000  1  0  0
# 3  3600  680000  1  0  0
# 4  4000  725000  1  0  0

# %%
model.fit(df.drop("price",axis=1),df.price)
# Out:
# LinearRegression()

# %%
model.score(df.drop("price",axis=1),df.price)
# Out:
# 0.9573929037221873

# %%
data=pd.read_csv("insurance_data.csv")
data
# Out:
#     age  bought_insurance
# 0    22                 0
# 1    25                 0
# 2    47                 1
# 3    52                 0
# 4    46                 1
# 5    56                 1
# 6    55                 0
# 7    60                 1
# 8    62                 1
# 9    61                 1
# 10   18                 0
# 11   28                 0
# 12   27                 0
# 13   29                 0
# 14   49                 1
# 15   55                 1
# 16   25                 1
# 17   58                 1
# 18   19                 0
# 19   18                 0
# 20   21                 0
# 21   26                 0
# 22   40                 1
# 23   45                 1
# 24   50                 1
# 25   54                 1
# 26   23                 0

# %%
from sklearn.linear_model import LinearRegression
from matplotlib import pyplot as plt

# %%
x=data[["age"]]
x
# Out:
#     age
# 0    22
# 1    25
# 2    47
# 3    52
# 4    46
# 5    56
# 6    55
# 7    60
# 8    62
# 9    61
# 10   18
# 11   28
# 12   27
# 13   29
# 14   49
# 15   55
# 16   25
# 17   58
# 18   19
# 19   18
# 20   21
# 21   26
# 22   40
# 23   45
# 24   50
# 25   54
# 26   23

# %%
y=data[["bought_insurance"]]
y
# Out:
#     bought_insurance
# 0                  0
# 1                  0
# 2                  1
# 3                  0
# 4                  1
# 5                  1
# 6                  0
# 7                  1
# 8                  1
# 9                  1
# 10                 0
# 11                 0
# 12                 0
# 13                 0
# 14                 1
# 15                 1
# 16                 1
# 17                 1
# 18                 0
# 19                 0
# 20                 0
# 21                 0
# 22                 1
# 23                 1
# 24                 1
# 25                 1
# 26                 0

# %%
plt.scatter(x,y)
plt.show()

# %%
model=LinearRegression()

# %%
model.fit(x,y)
# Out:
# LinearRegression()

# %%
pred=model.predict(21)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-57-b333fe5962cd> in <module>
# ----> 1 pred=model.predict(21)
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_base.py in predict(self, X)
#     236             Returns predicted values.
#     237         """
# --> 238         return self._decision_function(X)
#     239
#     240     _preprocess_data = staticmethod(_preprocess_data)
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_base.py in _decision_function(self, X)
#     218         check_is_fitted(self)
#     219
# --> 220         X = check_array(X, accept_sparse=['csr', 'csc', 'coo'])
#     221         return safe_sparse_dot(X, self.coef_.T,
#     222                                dense_output=True) + self.intercept_
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
# ...

# %%
model.score(x,y)
